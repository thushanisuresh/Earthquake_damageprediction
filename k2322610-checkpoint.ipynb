# %% [markdown]
# <h1 style="text-align:center";>Coursework - Practical Report</h1>
# <center>
#     <h2>C17340</h2>
#     <h3>Thushani Sureshkantha - K2322610</h3>
#     <h3>W.B Hiruni Sanjana Franando - K2326805</h3>
# </center>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#         }
#         ul {
#             list-style-type: none;
#         }
#         li {
#             margin-bottom: 10px;
#         }
#     </style>
# </head>
# <body>
#     <h1>Table of Contents</h1>
#     <ul>
#         <li><strong>1. Introduction</strong>
#             <ul>
#                 <li>Overview of the risks associated with natural disasters, specifically earthquakes.</li>
#                 <li>Importance of understanding various factors influencing earthquake damage.</li>
#             </ul>
#         </li>
#         <li><strong>2. Introduction to the Dataset</strong>
#             <ul>
#                 <li>Brief description of the dataset, including key features and target variable.</li>
#                 <li>Explanation of the data structure and types of information provided.</li>
#             </ul>
#         </li>
#         <li><strong>3. Installed Packages</strong>
#             <ul>
#                 <li>List of Python libraries imported for the analysis.</li>
#                 <li>Confirmation of setup completeness.</li>
#             </ul>
#         </li>
#         <li><strong>4. Import the Styles</strong>
#             <ul>
#                 <li>Setup for visual style of plots and inline display configurations.</li>
#             </ul>
#         </li>
#         <li><strong>5. Initial Data Analysis (IDA)</strong>
#             <ul>
#                 <li>Define the Dataset Files Path</li>
#                 <li>Function to Calculate File Size</li>
#                 <li>Function to Calculate SHA1 Checksum</li>
#                 <li>Function to Get File Extension</li>
#                 <li>Analyze File Properties</li>
#                 <li>Features Dataset Properties</li>
#                 <li>Targets Dataset Properties</li>
#                 <li>Analyze Dataset Content</li>
#                 <li>Feature Analysis</li>
#                 <li>Initial Data Quality Assessment</li>
#             </ul>
#         </li>
#         <li><strong>6. Data Transformation</strong>
#             <ul>
#                 <li>Data Merging</li>
#                 <li>Verify the Merge</li>
#                 <li>Change Data Type</li>
#                 <li>Data Sorting</li>
#                 <li>Data Deletion</li>
#             </ul>
#         </li>
#         <li><strong>7. Exploratory Data Analysis</strong>
#             <ul>
#                 <li>Finding Null Values and Dealing with Missing Values</li>
#                 <li>Correlation Structures, Distribution Characteristics</li>
#                 <li>Trends in Data Using Appropriate Visualization Tools</li>
#                 <li>Present the Results of Research Questions Using Appropriate Plots</li>
#             </ul>
#         </li>
#         <li><strong>8. Conclusion of Earthquake Damage Analysis</strong>
#             <ul>
#                 <li>Key Findings</li>
#                 <li>Detailed Observations</li>
#                 <li>Conclusive Summary</li>
#             </ul>
#         </li>
#     </ul>
# </body>
# </html>

# %% [markdown]
# <b>INTRODUCTION<b>
#
# Natural catastrophes, especially earthquakes, put infrastructure at serious risk, putting lives in jeopardy and resulting in large financial damages. A multitude of variables, such as the age, structural design, and location of the structure, as well as the materials used during construction, may significantly affect how severely an earthquake damages a building. Reducing possible damages in earthquake-prone locations, raising safety standards, and strengthening building resilience all depend on an understanding of these elements.
#
# The main emphasis of this paper is a thorough exploratory data analysis (EDA) of an extensive dataset that records different building attributes and the degree of seismic damage they sustained. The dataset offers a singular chance to investigate the link between building traits and earthquake susceptibility. It includes structural elements, materials employed, and other pertinent building metrics. We want to forecast the potential extent of a building's damage in the case of an earthquake by using this data, which is crucial for risk assessment and mitigation plans.
#
# The primary objectives of this analysis are to:
# 1.	Identify key factors that significantly influence the earthquake damage grade of buildings.
# 2.	Develop a predictive model to estimate potential damage outcomes based on building characteristics.
# 3.	Provide actionable insights and recommendations to stakeholders, including construction companies, policy makers, and disaster response teams, to inform better building practices and disaster preparedness plans.

# %% [markdown]
# <b>INTRODUCTION TO DATASET</b>
#
# Dataset Overview
# This dataset provides detailed information about buildings and their damage levels following an earthquake. Comprised of two main files, input_features.csv and target_values.csv, the dataset captures a wide range of structural and locational attributes for each building.
#
# Features:
#
# Structural Characteristics: Includes data on the number of floors, age, area, and height of the buildings.
# Construction Materials: Details the materials used in the superstructure such as timber, bamboo, adobe mud, and various types of mortar.
# Location: Described by three geographic levels from broad regions to specific sub-regions.
# Additional Uses: Information on secondary uses of the building like agricultural, hotel, or institutional purposes.
# Target Variable:
#
# Damage Grade: An ordinal variable that categorizes the extent of damage sustained by the buildings into three grades: low, medium, and high damage.

# %% [markdown]
# <h3>Installed Packages 📦</h3>

# %%
# Importing numpy for numerical operations on arrays and matrices
import numpy as np

# Importing pandas for data manipulation and analysis
import pandas as pd

# Importing pyplot from matplotlib for creating static, interactive, and animated visualizations
import matplotlib.pyplot as plt

# Importing seaborn for high-level interface for drawing attractive and informative statistical graphics
import seaborn as sns

# Importing train_test_split from sklearn.model_selection to split arrays or matrices into random train and test subsets
from sklearn.model_selection import train_test_split

# Printing a confirmation message to verify that setup is complete and libraries are loaded
print("Setup complete!")
# Out:
# Setup complete!

# %% [markdown]
# <h3>Import the Styles 💃</h3>

# %%
# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Ensures that plots are displayed in the notebook
# %matplotlib inline

# %% [markdown]
# <h2>Initial Data Analysis (IDA) 📝</h2>

# %% [markdown]
# <h4>Define the Dataset Files Path 🧭</h4>

# %%
features_path = 'input_features.csv'
targets_path = 'target_values.csv'

# %% [markdown]
# <h4> Function to Calculate File Size 📋</h4>

# %%
def get_file_size(file_path):
    """Return the file size in bytes and megabytes."""
    file_size_bytes = os.path.getsize(file_path)
    file_size_mb = file_size_bytes / (1024 * 1024)
    return file_size_mb, file_size_bytes

# %% [markdown]
# <h4>Function to Calculate SHA1 Checksum</h4>

# %%
def get_checksum(file_path):
    """Calculate the SHA1 checksum of a file."""
    sha1 = hashlib.sha1()
    with open(file_path, "rb") as f:
        while True:
            data = f.read(65536)  # Read the file in chunks of 65536 bytes
            if not data:
                break
            sha1.update(data)
    return sha1.hexdigest()

# %%
def get_file_extension(file_path):
    """Extract and return the file extension."""
    return os.path.splitext(file_path)[1][1:]

# %% [markdown]
# <h4>Analyze File Properties</h4>

# %%
def display_file_properties(file_path):
    file_name = os.path.basename(file_path)
    file_size_mb, file_size_bytes = get_file_size(file_path)
    file_extension = get_file_extension(file_path)
    checksum = get_checksum(file_path)
    
    print(f"File Name: {file_name}")
    print(f"File Size: {file_size_mb:.2f} MB ({file_size_bytes} bytes)")
    print(f"File Type: {file_extension.upper()}")
    print(f"SHA1 Checksum: {checksum}")
    print()  # Blank line for better readability between files

# %%
# Analyze the features dataset
print("Features Dataset Properties:")
display_file_properties(features_path)

# Analyze the target dataset
print("Targets Dataset Properties:")
display_file_properties(targets_path)
# Out:
# Features Dataset Properties:
# File Name: input_features.csv
# File Size: 22.36 MB (23442727 bytes)
# File Type: CSV
# SHA1 Checksum: 2faa1a97be42838e60e106f5518877095c41ead7
#
# Targets Dataset Properties:
# File Name: target_values.csv
# File Size: 2.22 MB (2330792 bytes)
# File Type: CSV
# SHA1 Checksum: 17fd8048f98b3005b71b5c4fe9afba396c793f4d

# %% [markdown]
# <h4>Analyze Dataset Content
# </h4>

# %%
df_primary = pd.read_csv(features_path)

row_count, column_count = df_primary.shape

print(f"Column Count: {column_count}")
print(f"Row Count: {row_count}")
# Out:
# Column Count: 39
# Row Count: 260601

# %% [markdown]
# <h4>Feature Analysis</h4>

# %%
df_primary.dtypes
# Out:
# building_id                                int64
# geo_level_1_id                             int64
# geo_level_2_id                             int64
# geo_level_3_id                             int64
# count_floors_pre_eq                        int64
# age                                        int64
# area_percentage                            int64
# height_percentage                          int64
# land_surface_condition                    object
# foundation_type                           object
# roof_type                                 object
# ground_floor_type                         object
# other_floor_type                          object
# position                                  object
# plan_configuration                        object
# has_superstructure_adobe_mud               int64
# has_superstructure_mud_mortar_stone        int64
# has_superstructure_stone_flag              int64
# has_superstructure_cement_mortar_stone     int64
# ...

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         table {
#             width: 100%;
#             border-collapse: collapse;
#         }
#         th, td {
#             border: 1px solid #dddddd;
#             text-align: left;
#             padding: 8px;
#         }
#         th {
#             background-color: #f2f2f2;
#         }
#     </style>
# </head>
# <body>
#     <table>
#         <thead>
#             <tr>
#                 <th>Attribute</th>
#                 <th>Description</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td>building_id</td>
#                 <td>Unique identifier for each building.</td>
#             </tr>
#             <tr>
#                 <td>geo_level_1_id</td>
#                 <td>Identifier for a geographic region at the broadest level.</td>
#             </tr>
#             <tr>
#                 <td>geo_level_2_id</td>
#                 <td>Identifier for a geographic sub-region within level 1.</td>
#             </tr>
#             <tr>
#                 <td>geo_level_3_id</td>
#                 <td>Identifier for a more specific geographic area within level 2.</td>
#             </tr>
#             <tr>
#                 <td>count_floors_pre_eq</td>
#                 <td>Number of floors in the building before the earthquake.</td>
#             </tr>
#             <tr>
#                 <td>age</td>
#                 <td>Age of the building in years.</td>
#             </tr>
#             <tr>
#                 <td>area_percentage</td>
#                 <td>Normalized area of the building's footprint.</td>
#             </tr>
#             <tr>
#                 <td>height_percentage</
#                 <td>Normalized height of the building's footprint.</td>
#             </tr>
#             <tr>
#                 <td>land_surface_condition</td>
#                 <td>Surface condition of the land where the building was built (categorical).</td>
#             </tr>
#             <tr>
#                 <td>foundation_type</td>
#                 <td>Type of foundation used in the building (categorical).</td>
#             </tr>
#             <tr>
#                 <td>roof_type</td>
#                 <td>Type of roof used on the building (categorical).</td>
#             </tr>
#             <tr>
#                 <td>ground_floor_type</td>
#                 <td>Type of the ground floor (categorical).</td>
#             </tr>
#             <tr>
#                 <td>other_floor_type</td>
#                 <td>Type of construction used in floors above the ground (categorical).</td>
#             </tr>
#             <tr>
#                 <td>position</td>
#                 <td>Position of the building (categorical).</td>
#             </tr>
#             <tr>
#                 <td>plan_configuration</td>
#                 <td>Configuration of the building plan (categorical).</td>
#             </tr>
#             <tr>
#                 <td>has_superstructure_adobe_mud</td>
#                 <td>Indicates if the superstructure was made of Adobe/Mud (binary).</td>
#             </tr>
#             <tr>
#                 <td>has_superstructure_mud_mortar_stone</td>
#                 <td>Indicates if the superstructure was made of Mud Mortar - Stone (binary).</td>
#             </tr>
#             <tr>
#                 <td>has_superstructure_stone_flag</td>
#                 <td>Indicates if the superstructure was made of Stone (binary).</td>
#             </tr>
#             <tr>
#                 <td>has_superstructure_cement_mortar_stone</td>
#                 <td>Indicates if the superstructure was made of Cement Mortar - Stone (binary).</td>
#             </tr>
#             <tr>
#                 <td>has_superstructure_mud_mortar_brick</td>
#                 <td>Indicates if the superstructure was made of Mud Mortar - Brick (binary).</td>
#             </tr>
#             <tr>
#                 <td>has_superstructure_cement_mortar_brick</td>
#                 <td>Indicates if the superstructure was made of Cement Mortar - Brick (binary).</td>
#             </tr>
#             <tr>
#                 <td>has_superstructure_timber</td>
#                 <td>Indicates if the superstructure was made of Timber (binary).</td>
#             </tr>
#             <tr>
#                 <td>has_superstructure_bamboo</td>
#                 <td>Indicates if the superstructure was made of Bamboo (binary).</td>
#             </tr>
#             <tr>
#                 <td>has_superstructure_rc_non_engineered</td>
#                 <td>Indicates if the superstructure was made of non-engineered reinforced concrete (binary).</td>
#             </tr>
#             <tr>
#                 <td>has_superstructure_rc_engineered</td>
#                 <td>Indicates if the superstructure was made of engineered reinforced concrete (binary).</td>
#             </tr>
#             <tr>
#                 <td>has_superstructure_other</td>
#                 <td>Indicates if the superstructure was made of any other materials (binary).</td>
#             </tr>
#             <tr>
#                 <td>legal_ownership_status</td>
#                 <td>Legal ownership status of the land where the building is located (categorical).</td>
#             </tr>
#             <tr>
#                 <td>count_families</td>
#                 <td>Number of families living in the building.</td>
#             </tr>
#             <tr>
#                 <td>has_secondary_use</td>
#                 <td>Indicates if the building was used for any secondary purposes (binary).</td>
#             </tr>
#             <tr>
#                 <td>has_secondary_use_agriculture</td>
#                 <td>Indicates if the building was used for agricultural purposes (binary).</td>
#             </tr>
#             <tr>
#                 <td>has_secondary_use_hotel</td>
#                 <td>Indicates if the building was used as a hotel (binary).</td>
#             </tr>
#             <tr>
#                 <td>has_secondary_use_rental</td>
#                 <td>Indicates if the building was used for rental purposes (binary).</td>
#             </tr>
#             <tr>
#                 <td>has_secondary_use_institution</td>
#                 <td>Indicates if the building was used as an institution (binary)</td>
#             </tr>
#             <tr>
#                 <td>has_secondary_use_school</td>
#                 <td>Indicates if the building was used as a school (binary).</td>
#             </tr>
#             <tr>
#                 <td>has_secondary_use_industry</td>
#                 <td>Indicates if the building was used for industrial purposes (binary).</td>
#             </tr>
#             <tr>
#                 <td>has_secondary_use_health_post</td>
#                 <td>Indicates if the building was used as a health post (binary).</td>
#             </tr>
#             <tr>
#                 <td>has_secondary_use_gov_office</td>
#                 <td>Indicates if the building was used as a government office (binary).</td>
#             </tr>
#             <tr>
#                 <td>has_secondary_use_use_police</td>
#                 <td>Indicates if the building was used as a police station (binary).</td>
#             </tr>
#             <tr>
#                 <td>has_secondary_use_other</td>
#                 <td>Indicates if the building was used for other secondary purposes (binary).</td>
#             </tr>
#         </tbody>
#     </table>

# %% [markdown]
# <h3>Initial Data Quality Assessment</h3>

# %% [markdown]
# <h4>Check Missing Values</h4>

# %%
def check_for_missing_data(df):
    null_data_sum = df.isnull().sum()
    null_data_result = pd.DataFrame(
        {"Count": null_data_sum, "Percentage": round((df.isnull().sum() / len(df)) * 100, 2)})
    print(null_data_result)


check_for_missing_data(df_primary)
# Out:
#                                         Count  Percentage
# building_id                                 0         0.0
# geo_level_1_id                              0         0.0
# geo_level_2_id                              0         0.0
# geo_level_3_id                              0         0.0
# count_floors_pre_eq                         0         0.0
# age                                         0         0.0
# area_percentage                             0         0.0
# height_percentage                           0         0.0
# land_surface_condition                      0         0.0
# foundation_type                             0         0.0
# roof_type                                   0         0.0
# ground_floor_type                           0         0.0
# other_floor_type                            0         0.0
# position                                    0         0.0
# plan_configuration                          0         0.0
# ...

# %% [markdown]
# <h4>Uniqueness Validation</h4>

# %%
# Count of unique building IDs
unique_count = df_primary['building_id'].nunique()
print("Number of unique building IDs:", unique_count)
# Counting duplicates
duplicate_count = df_primary['building_id'].duplicated().sum()
print("Number of duplicate building IDs:", duplicate_count)
# Total number of entries
total_count = df_primary['building_id'].count()
print("Total number of entries:", total_count)
# Out:
# Number of unique building IDs: 260601
# Number of duplicate building IDs: 0
# Total number of entries: 260601

# %% [markdown]
# <h4> Validation of Accuracy and Consistency </h4>

# %%
import matplotlib.pyplot as plt

# Outlier detection
# Visual outlier detection using box plots
def generate_outlier_detection_plots(df):
    plt.figure(figsize=(15, 8))  # Adjusting figure size for better visibility

    # Creating box plots for each specified column
    columns = ['age', 'area_percentage', 'height_percentage', 'count_floors_pre_eq', 'has_superstructure_mud_mortar_stone']
    for i, column in enumerate(columns):
        plt.subplot(2, 3, i + 1)  # Ensure proper indexing in subplot
        plt.boxplot(df[column].dropna())  # Drop NA values for clean plotting
        plt.title(column)

    plt.tight_layout()  # Adjust layout to prevent overlap
    plt.show()  # Display the plots

# Example usage
generate_outlier_detection_plots(df_primary)

# %% [markdown]
# The box plots represent a dataset of buildings, indicating that most are newer with fewer floors and modest footprints. Outliers suggest the presence of significantly older and larger buildings. Additionally, the prevalent use of mud mortar stone in construction is evident.

# %% [markdown]
# <h3>Quality of data</h3>

# %% [markdown]
# <h4> Frequency counts</h4>

# %%
# Frequency counts for 'land_surface_condition'
land_surface_condition_counts = df_primary['land_surface_condition'].value_counts().to_frame('Frequency')
print("Frequency Counts for Land Surface Condition:")
print(land_surface_condition_counts)

# Frequency counts for 'foundation_type'
foundation_type_counts = df_primary['foundation_type'].value_counts().to_frame('Frequency')
print("\nFrequency Counts for Foundation Type:")
print(foundation_type_counts)

# Frequency counts for 'roof_type'
roof_type_counts = df_primary['roof_type'].value_counts().to_frame('Frequency')
print("\nFrequency Counts for Roof Type:")
print(roof_type_counts)

# Frequency counts for 'ground_floor_type'
ground_floor_type_counts = df_primary['ground_floor_type'].value_counts().to_frame('Frequency')
print("\nFrequency Counts for Ground Floor Type:")
print(ground_floor_type_counts)

# Frequency counts for 'other_floor_type'
other_floor_type_counts = df_primary['other_floor_type'].value_counts().to_frame('Frequency')
print("\nFrequency Counts for Other Floor Type:")
print(other_floor_type_counts)

# Frequency counts for 'position'
position_counts = df_primary['position'].value_counts().to_frame('Frequency')
print("\nFrequency Counts for Position:")
print(position_counts)

# Frequency counts for 'plan_configuration'
plan_configuration_counts = df_primary['plan_configuration'].value_counts().to_frame('Frequency')
print("\nFrequency Counts for Plan Configuration:")
print(plan_configuration_counts)

# Frequency counts for 'legal_ownership_status'
legal_ownership_status_counts = df_primary['legal_ownership_status'].value_counts().to_frame('Frequency')
print("\nFrequency Counts for Legal Ownership Status:")
print(legal_ownership_status_counts)
# Out:
# Frequency Counts for Land Surface Condition:
#                         Frequency
# land_surface_condition
# t                          216757
# n                           35528
# o                            8316
#
# Frequency Counts for Foundation Type:
#                  Frequency
# foundation_type
# r                   219196
# w                    15118
# u                    14260
# i                    10579
# h                     1448
#
# Frequency Counts for Roof Type:
#            Frequency
# roof_type
# n             182842
# q              61576
# x              16183
#
# Frequency Counts for Ground Floor Type:
#                    Frequency
# ground_floor_type
# f                     209619
# x                      24877
# v                      24593
# z                       1004
# m                        508
#
# Frequency Counts for Other Floor Type:
#                   Frequency
# other_floor_type
# q                    165282
# x                     43448
# ...

# %% [markdown]
# <h4> Descriptive/Summary Statistics</h4>

# %% [markdown]
# Filter Numeric Columns

# %%
# Select only numeric columns for descriptive statistics
numeric_features = df_primary.select_dtypes(include=[np.number])

# Generate descriptive statistics
statistics = numeric_features.describe()

# Include the median by adding it separately, as describe() does not include it by default
median = numeric_features.median()
statistics.loc['median'] = median

# %%
# Define the number of columns per chunk
cols_per_chunk = 8

# Calculate the total number of chunks needed
total_chunks = (len(numeric_features.columns) + cols_per_chunk - 1) // cols_per_chunk

# Display each chunk of columns as a separate table
for i in range(total_chunks):
    start_col = i * cols_per_chunk
    end_col = start_col + cols_per_chunk
    display(statistics.iloc[:, start_col:end_col])
# Out:
#          building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq            age  area_percentage  height_percentage
# count   2.606010e+05   260601.000000   260601.000000   260601.000000        260601.000000  260601.000000    260601.000000      260601.000000
# mean    5.256755e+05       13.900353      701.074685     6257.876148             2.129723      26.535029         8.018051           5.434365
# std     3.045450e+05        8.033617      412.710734     3646.369645             0.727665      73.565937         4.392231           1.918418
# min     4.000000e+00        0.000000        0.000000        0.000000             1.000000       0.000000         1.000000           2.000000
# 25%     2.611900e+05        7.000000      350.000000     3073.000000             2.000000      10.000000         5.000000           4.000000
# ...

# %% [markdown]
# <h4>Normality (Frequency Histograms)</h4>

# %%
import matplotlib.pyplot as plt

# List of numerical columns you want to plot histograms for
numerical_columns = ['geo_level_1_id', 'geo_level_2_id', 'geo_level_3_id', 
                     'count_floors_pre_eq', 'age', 'area_percentage', 'height_percentage', 'count_families']

# Loop through the list and create a histogram for each numerical column
for column in numerical_columns:
    df_primary[column].hist(bins=20)  # Adjust bin size as needed
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# <h3>Data Transformation</h3>

# %% [markdown]
# <h4>Data Merging</h4>

# %%
# Create DataFrames for displaying columns
features_columns = pd.DataFrame({'Features Columns': features.columns})
targets_columns = pd.DataFrame({'Targets Columns': targets.columns})

# Display the DataFrames as tables
display(features_columns)
display(targets_columns)
# Out:
#                           Features Columns
# 0                              building_id
# 1                           geo_level_1_id
# 2                           geo_level_2_id
# 3                           geo_level_3_id
# 4                      count_floors_pre_eq
# 5                                      age
# 6                          area_percentage
# 7                        height_percentage
# 8                   land_surface_condition
# 9                          foundation_type
# 10                               roof_type
# 11                       ground_floor_type
# 12                        other_floor_type
# 13                                position
# 14                      plan_configuration
# 15            has_superstructure_adobe_mud
# 16     has_superstructure_mud_mortar_stone
# 17           has_superstructure_stone_flag
# 18  has_superstructure_cement_mortar_stone
# 19     has_superstructure_mud_mortar_brick
# 20  has_superstructure_cement_mortar_brick
# ...

# %% [markdown]
# Merge Data

# %%
merged_data = pd.merge(features, targets, on='building_id', how='inner')

# %% [markdown]
# Verify the Merge

# %%
print(merged_data.shape)
print(merged_data.isnull().sum())
# Out:
# (260601, 40)
# building_id                               0
# geo_level_1_id                            0
# geo_level_2_id                            0
# geo_level_3_id                            0
# count_floors_pre_eq                       0
# age                                       0
# area_percentage                           0
# height_percentage                         0
# land_surface_condition                    0
# foundation_type                           0
# roof_type                                 0
# ground_floor_type                         0
# other_floor_type                          0
# position                                  0
# plan_configuration                        0
# has_superstructure_adobe_mud              0
# has_superstructure_mud_mortar_stone       0
# has_superstructure_stone_flag             0
# has_superstructure_cement_mortar_stone    0
# has_superstructure_mud_mortar_brick       0
# has_superstructure_cement_mortar_brick    0
# ...

# %% [markdown]
# Save or Continue Processing

# %%
merged_data.to_csv('merged_dataset.csv', index=False)

# %% [markdown]
# <h4>Change Data Type<h4>

# %%
data['land_surface_condition'] = data['land_surface_condition'].astype('category')

# %% [markdown]
# <h4>Data Sorting</h4>

# %%
data_sorted = data.sort_values(by='age')

# %% [markdown]
# <h4>Data Deletion</h4>
#
# When deciding to drop columns such as `has_secondary_use_use_police`, `has_secondary_use_health_post`, and `has_secondary_use_gov_office` from the dataset, the primary consideration is their limited impact on the predictive modeling of building damage due to earthquakes. These columns likely represent rare use cases of buildings, potentially leading to sparse data that does not significantly contribute to or could skew the analysis. Furthermore, if preliminary correlation analysis indicates that these features have minimal correlation with the target variable (`damage_grade`), their exclusion helps streamline the dataset, reducing complexity and focusing the model on more impactful variables. This approach ensures that the analysis remains robust and the model more generalizable, avoiding overfitting on less relevant features.

# %%
columns_to_drop = ['has_secondary_use_use_police', 'has_secondary_use_health_post', 'has_secondary_use_gov_office']  # example list
data.drop(columns=columns_to_drop, inplace=True)

# %%
import pandas as pd

# Assuming 'data' is your merged DataFrame
data = pd.read_csv('merged_dataset.csv')  # Load your dataset if not already loaded

# Summary of the dataset
summary = pd.DataFrame({
    "Data Type": data.dtypes,
    "Non-Null Count": data.notnull().sum(),
    "Unique Count": data.nunique()
}).reset_index()

summary.rename(columns={'index': 'Feature'}, inplace=True)

summary
# Out:
#                                    Feature Data Type  Non-Null Count  Unique Count
# 0                              building_id     int64          260601        260601
# 1                           geo_level_1_id     int64          260601            31
# 2                           geo_level_2_id     int64          260601          1414
# 3                           geo_level_3_id     int64          260601         11595
# 4                      count_floors_pre_eq     int64          260601             9
# 5                                      age     int64          260601            42
# 6                          area_percentage     int64          260601            84
# 7                        height_percentage     int64          260601            27
# 8                   land_surface_condition    object          260601             3
# 9                          foundation_type    object          260601             5
# ...

# %% [markdown]
# Plot Non-Null Count:

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
summary['Non-Null Count'].plot(kind='barh')
plt.xlabel('Non-Null Count')
plt.title('Non-Null Values Count by Feature')
plt.yticks(ticks=range(len(summary)), labels=summary['Feature'])
plt.show()

# %% [markdown]
# The horizontal bar chart shows that all features in the dataset have a complete set of non-null entries, indicating no missing data across all variables.

# %% [markdown]
# <b>Plot Unique Values Count</b>

# %%
plt.figure(figsize=(10, 8))
summary['Unique Count'].plot(kind='barh', color='green')
plt.xlabel('Unique Count')
plt.title('Unique Values Count by Feature')
plt.yticks(ticks=range(len(summary)), labels=summary['Feature'])
plt.show()

# %% [markdown]
# <h4>Basic Plots</h4>

# %% [markdown]
# Distribution of Building Age

# %%
# Histogram of the 'age' of buildings
plt.hist(data['age'], bins=20, color='blue', edgecolor='black')
plt.title('Distribution of Building Age')
plt.xlabel('Age (years)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# The histogram depicts the distribution of building ages, showing a large majority of buildings are very young, with ages close to zero, and a few much older buildings, as indicated by the long tail towards the right.

# %% [markdown]
# <b>area_percentage</b>

# %%
# Box plot for 'area_percentage'
sns.boxplot(y=data['area_percentage'])
plt.title('Box Plot of Area Percentage')
plt.ylabel('Area Percentage')
plt.show()

# %% [markdown]
# The box plot shows a skewed distribution of area percentages for buildings, with a concentration at lower values and several high-value outliers.

# %% [markdown]
# <b>chart of roof types</b>

# %%
# Bar chart of roof types
roof_type_counts = data['roof_type'].value_counts()
plt.bar(roof_type_counts.index, roof_type_counts.values, color='green')
plt.title('Frequency of Roof Types')
plt.xlabel('Roof Type')
plt.ylabel('Frequency')
plt.xticks(rotation=45)  # Rotates labels to prevent overlap
plt.show()

# %% [markdown]
# The bar chart displays the frequency of three different roof types in a dataset. The most common roof type, represented by the first bar, significantly outnumbers the others, while the second bar shows less frequency, and the third type is the least common.

# %% [markdown]
# <b>plot of 'age' vs 'number of floors</b>

# %%
# Scatter plot of 'age' vs 'number of floors'
plt.scatter(data['age'], data['count_floors_pre_eq'], alpha=0.5)
plt.title('Age vs Number of Floors')
plt.xlabel('Age (years)')
plt.ylabel('Number of Floors')
plt.show()

# %% [markdown]
# The scatter plot compares the age of buildings to their number of floors. It shows that buildings of various ages have a range of floor numbers, but most are concentrated at lower ages and fewer floors. There’s a sparse distribution for older buildings and those with more floors.

# %% [markdown]
# <b>plot for foundation type</b>

# %%
# Count plot for foundation type
sns.countplot(x='foundation_type', data=data)
plt.title('Distribution of Foundation Types')
plt.xlabel('Foundation Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The bar chart displays the distribution of different foundation types in a dataset, showing a predominant preference for one type of foundation over the others, which appear much less frequently.

# %% [markdown]
# <b>land surface condition</b>

# %%
# Pie chart for land surface condition
land_surface_counts = data['land_surface_condition'].value_counts()
plt.pie(land_surface_counts, labels=land_surface_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Land Surface Condition Distribution')
plt.show()

# %% [markdown]
# The pie chart illustrates the distribution of land surface conditions categorized into three types, with the largest portion being type 't' at 83.2%, followed by type 'n' at 13.6%, and the smallest segment being type 'o' at 3.2%.

# %% [markdown]
# <b>the median age of buildings by number of floors</b>

# %%
# Line plot for the median age of buildings by number of floors
median_age_by_floors = data.groupby('count_floors_pre_eq')['age'].median()
plt.plot(median_age_by_floors.index, median_age_by_floors.values)
plt.title('Median Age of Buildings by Number of Floors')
plt.xlabel('Number of Floors')
plt.ylabel('Median Age (years)')
plt.show()

# %% [markdown]
# The line graph portrays the median age of buildings relative to the number of floors, displaying a varied relationship: Buildings with one floor have a median age around 15 years, which then dips for two-floor buildings. The median age peaks at around 60 years for buildings with five floors, decreases again for those with six to eight floors, and finally increases for buildings with nine floors.

# %% [markdown]
# <h3>Correlation Analysis</h3>

# %%
# Assuming features and target are already loaded into `features` and `targets`
data = pd.merge(features, targets, on='building_id')

# %%
# Selecting only numeric columns for correlation
numeric_data = data.select_dtypes(include=[np.number])
correlation_matrix = numeric_data.corr()

# Visualizing the correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix of Numerical Building Features')
plt.show()

# %% [markdown]
# <h2>Exploratory Data Analysis</h2>

# %% [markdown]
# <h3>Finding Null Values and Dealing with Missing Values</h3>

# %%
missing_values = data.isnull().sum()
print(missing_values[missing_values > 0])
# Out:
# Series([], dtype: int64)

# %% [markdown]
# <h3>Correlation Structures, Distribution Characteristics</h3>

# %%
key_columns = ['age', 'geo_level_1_id', 'geo_level_2_id', 'geo_level_3_id', 'count_floors_pre_eq', 'foundation_type', 'roof_type']

# Filter the dataset to include only these key columns plus the target variable
important_data = data[key_columns + ['damage_grade']]

# Convert categorical columns to numeric using one-hot encoding
# First, identify categorical columns within the key columns
categorical_cols = important_data.select_dtypes(include=['object']).columns
important_data_encoded = pd.get_dummies(important_data, columns=categorical_cols, drop_first=True)

# Calculate the correlation matrix on the numeric dataset
correlation_matrix = important_data_encoded.corr()

# Plot the correlation matrix using a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix for Key Variables')
plt.show()

# %% [markdown]
# <h4>Analyze Distributions</h4>

# %%
sns.histplot(data['age'], kde=True, color='blue')
plt.title('Distribution of Building Age')
plt.xlabel('Age')
plt.show()

# %% [markdown]
# The line graph portrays the median age of buildings relative to the number of floors, displaying a varied relationship: Buildings with one floor have a median age around 15 years, which then dips for two-floor buildings. The median age peaks at around 60 years for buildings with five floors, decreases again for those with six to eight floors, and finally increases for buildings with nine floors.

# %% [markdown]
# <h2>Analyze Distributions</h4>

# %% [markdown]
# <h3> Trends in Data Using Appropriate Visualization Tools</h3>

# %% [markdown]
# <h4>Trend Analysis</h4>

# %%
plt.figure(figsize=(10, 5))
# Assuming the 'age' column represents the age of the building at the time of the earthquake
data.groupby('age')['damage_grade'].mean().plot(kind='line')
plt.title('Average Damage Grade by Building Age')
plt.xlabel('Building Age (years)')
plt.ylabel('Average Damage Grade')
plt.show()

# %% [markdown]
# The graph shows the average damage grade of buildings plotted against their age. Initially, there's a sharp fluctuation in the damage grade for the youngest buildings, which stabilizes as the age increases. Overall, the trend line indicates a slight decrease in the average damage grade as the building age grows, suggesting older buildings may have experienced slightly less damage on average.

# %% [markdown]
# <h2>Present the Results of Research Questions Using Appropriate Plots</h2>

# %% [markdown]
# <h4>Building Age and Material vs. Damage Grade</h4>

# %%
# Plotting
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
scatter_plot = sns.scatterplot(x='age', y='damage_grade', hue='foundation_type', data=data, palette='viridis', s=100)
plt.title('Effect of Age and Foundation Type on Earthquake Damage Grade')  # Title of the plot
plt.xlabel('Building Age (years)')  # X-axis label
plt.ylabel('Earthquake Damage Grade')  # Y-axis label
plt.legend(title='Foundation Type')  # Legend with a title
plt.grid(True)  # Adding grid for better readability
plt.show()

# %% [markdown]
# The scatter plot depicts the earthquake damage grade in relation to the building age, with each point color-coded to represent different foundation types. Most data points cluster at the lower end of the age spectrum, indicating younger buildings, with damage grades predominantly at the upper limit, suggesting higher damage levels. The spread of damage grades across various foundation types seems fairly consistent regardless of age, although there are fewer data points for older buildings.

# %% [markdown]
# <h4>Geographic Region and Building Damage</h4>

# %%
# Assuming geo_level_1_id represents a broad geographical region
plt.figure(figsize=(12, 6))
sns.boxplot(x='geo_level_1_id', y='damage_grade', data=data)
plt.title('Damage Grade by Geographic Region')
plt.xlabel('Geographic Region')
plt.ylabel('Damage Grade')
plt.show()

# %% [markdown]
# The bar chart compares the damage grade across different geographic regions, showing that the level of damage is consistently high (around the maximum of 3) across most regions. A few regions exhibit slightly lower damage grades, as indicated by the height of the bars. Outliers are present in several regions, suggesting variations in damage within those areas.

# %% [markdown]
# <h4>Building Use and Vulnerability to Earthquake Damage</h4>

# %%
# Assuming 'building_use' is encoded as binary flags across multiple columns
use_columns = [col for col in data.columns if 'use_' in col]
avg_damage_by_use = data[use_columns + ['damage_grade']].groupby('damage_grade').mean()
avg_damage_by_use.plot(kind='bar', figsize=(10, 6))
plt.title('Average Damage Grade by Building Use')
plt.xlabel('Damage Grade')
plt.ylabel('Proportion of Use Types')
plt.show()

# %% [markdown]
# The bar chart illustrates the average damage grade attributed to buildings based on their secondary use. Buildings used for agriculture, hotels, rentals, institutions, schools, industry, health posts, government offices, police, and other purposes show varying levels of damage. Notably, buildings with secondary use as 'other' exhibit a higher proportion of the most severe damage grade compared to other categories. The chart indicates that secondary usage may correlate with the degree of damage experienced during an event such as an earthquake.

# %% [markdown]
# <h4>Construction Styles and Damage Severity</h4>

# %%
sns.catplot(x='roof_type', y='damage_grade', kind='violin', data=data)
plt.title('Damage Grade Distribution by Roof Type')
plt.xlabel('Roof Type')
plt.ylabel('Damage Grade')
plt.show()

# %% [markdown]
# The violin plot depicts the distribution of damage grades across different roof types. Each violin shape represents the probability density of the data at different damage grades for roof types 'n', 'q', and 'x'. The width of each section indicates the proportion of data points at each damage grade. All three roof types show a similar range of damage grades from 1 to 3, with the median damage grade for each type lying between 2 and 3, suggesting that none of the roof types completely mitigates damage. Roof type 'x' shows the most variability in damage grades.

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
#
# <style>
#   body {font-family: Arial, sans-serif; line-height: 1.6;}
#   .container {width: 75%; margin: auto; padding: 20px;}
#   h1, h2 {text-align: center;}
#   h1 {color: #333;}
#   p {text-align: justify;}
#   .summary {background-color: #f8f8f8; padding: 10px; margin-top: 20px;}
# </style>
# </head>
# <body>
# <div class="container">
#   <h1>Conclusion of Earthquake Damage Analysis</h1>
#
#   <h2>Key Findings</h2>
#   <p>
#     The visual analysis of the building dataset with respect to earthquake damage reveals several key insights. Younger buildings dominate the dataset and show a wide range of damage grades. Interestingly, there is a general trend of decreasing average damage grade with increasing building age. This could indicate that factors such as newer construction methods or materials might contribute to greater earthquake resilience.
#   </p>
#
#   <div class="summary">
#     <h2>Detailed Observations</h2>
#     <p>
#       <strong>Building Age and Damage Grade:</strong> A non-linear relationship was observed, with younger buildings generally showing higher damage grades. Older buildings displayed a decrease in damage grade, suggesting that factors other than age contribute to building resilience.
#     </p>
#     <p>
#       <strong>Foundation Type:</strong> All foundation types experienced a range of damage grades, suggesting that newer buildings' construction techniques, regardless of foundation type, might be more effective against earthquakes.
#     </p>
#     <p>
#       <strong>Geographic Variability:</strong> The median damage grade was consistently high across most geographic regions, indicating regional influences on damage severity, possibly due to local construction practices and seismic activity.
#     </p>
#     <p>
#       <strong>Building Use:</strong> Secondary use of buildings did not show a significant impact on the damage grade, indicating that structural integrity factors are potentially more critical.
#     </p>
#     <p>
#       <strong>Roof Type:</strong> While all roof types showed a wide range of damage grades, there was a slight indication that certain types may offer slightly better resilience.
#     </p>
#   </div>
#
#   <h2>Conclusive Summary</h2>
#   <p>
#     The analysis concludes that earthquake damage to buildings is influenced by a complex interplay of factors. While age and foundation type do show some correlation with damage outcomes, they are not exclusive predictors. Regional factors and construction practices also play a crucial role in the extent of earthquake damage. The insights from this analysis can be instrumental for policymakers and engineers in improving construction codes and designing more effective earthquake resilience measures.
#   </p>
#
# </div>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 20px;
#         }
#         ul {
#             list-style-type: none;
#         }
#         li {
#             margin-bottom: 10px;
#         }
#     </style>
# </head>
# <body>
#     <h2>Recommendations for Enhancing Earthquake Resilience</h2>
#     <ul>
#         <li>Assess the resilience of newer versus older construction materials and techniques.</li>
#         <li>Perform detailed seismic risk assessments for tailored building regulations.</li>
#         <li>Investigate the correlation between roof and foundation types with damage grades.</li>
#         <li>Study the impact of secondary uses on structural integrity and develop multi-use guidelines.</li>
#         <li>Maintain high-quality, complete datasets to support robust policy decisions.</li>
#         <li>Implement training for builders and engineers on earthquake-resistant construction practices.</li>
#         <li>Encourage retrofitting of existing buildings to meet modern seismic standards.</li>
#         <li>Integrate seismic risk assessments into urban planning and development.</li>
#         <li>Update building regulations based on findings of damage distribution analyses.</li>
#         <li>Promote community awareness about earthquake-resistant designs.</li>
#         <li>Invest in R&D for new materials and designs to reduce earthquake damage.</li>
#         <li>Offer insurance incentives for compliance with seismic standards.</li>
#         <li>Strengthen emergency preparedness in areas with higher damage grades.</li>
#         <li>Collaborate with experts for a comprehensive approach to earthquake resilience.</li>
#     </ul>
# </body>
# </html>
